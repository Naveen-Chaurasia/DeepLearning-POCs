# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.tail()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[1:3]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature']>32
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: temperature, dtype: bool

# %%
df[df['temperature']>32]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df['day'][df['temperature'] == df['temperature'].max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df[df['temperature'] == df['temperature'].max()] # Kinda doing SQL in pandas
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.set_index('day', inplace=True)
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.iloc[1:5]
# Out:
#           temperature  windspeed  event
# day
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain

# %%
df.iloc[1:5,1:2]
# Out:
#           windspeed
# day
# 1/2/2017          7
# 1/3/2017          2
# 1/4/2017          7
# 1/5/2017          4

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df.index
# Out:
# Index(['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'], dtype='object', name='day')

# %%
df.set_index('event',inplace=True) # this is kind of building a hash map using event as a key
df
# Out:
#        temperature  windspeed
# event
# Rain            32          6
# Sunny           35          7
# Snow            28          2
# Snow            24          7
# Rain            32          4
# Sunny           31          2

# %%
df.loc['Snow']
# Out:
#        temperature  windspeed
# event
# Snow            28          2
# Snow            24          7

# %% [markdown]
# # Tuple List

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# # Using List of Dictionaries

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# # Write csv

# %%
t=df.to_csv('new.csv')
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.to_csv('new.csv',header=False)

# %%
df=pd.read_csv('new.csv')
df
# Out:
#    0  1/1/2017  32  6   Rain
# 0  1  1/2/2017  35  7  Sunny
# 1  2  1/3/2017  28  2   Snow
# 2  3  1/4/2017  24  7   Snow
# 3  4  1/5/2017  32  4   Rain
# 4  5  1/6/2017  31  2  Sunny

# %% [markdown]
# # Replacing single value

# %%
import numpy as np
new_df = df.replace(7, value=np.NaN)
new_df
# Out:
#    0  1/1/2017  32    6   Rain
# 0  1  1/2/2017  35  NaN  Sunny
# 1  2  1/3/2017  28  2.0   Snow
# 2  3  1/4/2017  24  NaN   Snow
# 3  4  1/5/2017  32  4.0   Rain
# 4  5  1/6/2017  31  2.0  Sunny

# %% [markdown]
# # Replacing list of values

# %%
new_df = df.replace(to_replace=[-99999,-88888], value=0)
new_df
# Out:
#    0  1/1/2017  32  6   Rain
# 0  1  1/2/2017  35  7  Sunny
# 1  2  1/3/2017  28  2   Snow
# 2  3  1/4/2017  24  7   Snow
# 3  4  1/5/2017  32  4   Rain
# 4  5  1/6/2017  31  2  Sunny

# %%
df
# Out:
#    0  1/1/2017  32  6   Rain
# 0  1  1/2/2017  35  7  Sunny
# 1  2  1/3/2017  28  2   Snow
# 2  3  1/4/2017  24  7   Snow
# 3  4  1/5/2017  32  4   Rain
# 4  5  1/6/2017  31  2  Sunny

# %% [markdown]
# # Write to Excel

# %%
df.to_excel("new.xlsx", sheet_name="stocks", index=False, startrow=2, startcol=1)

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})
with pd.ExcelWriter('stocks_weather.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")

# %%
# https://www.geeksforgeeks.org/pandas-tutorial/

# %%
# importing pandas as pd
import pandas as pd
  
# Creating the Series
sr = pd.Series([11, 21, 8, 18, 65, 18, 32, 10, 5, 32, None])
  
# Create the Index
# apply yearly frequency
index_ = pd.date_range('2010-10-09 08:45', periods = 11, freq ='Y')
  
# set the index
sr.index = index_
  
# Print the series
print(sr)
# return True if greater than 30
# else return False
result = sr.apply(lambda x : True if x>30 else False)
  
# Print the result
print(result)
# Out:
# 2010-12-31 08:45:00    11.0
# 2011-12-31 08:45:00    21.0
# 2012-12-31 08:45:00     8.0
# 2013-12-31 08:45:00    18.0
# 2014-12-31 08:45:00    65.0
# 2015-12-31 08:45:00    18.0
# 2016-12-31 08:45:00    32.0
# 2017-12-31 08:45:00    10.0
# 2018-12-31 08:45:00     5.0
# 2019-12-31 08:45:00    32.0
# 2020-12-31 08:45:00     NaN
# Freq: A-DEC, dtype: float64
# 2010-12-31 08:45:00    False
# 2011-12-31 08:45:00    False
# 2012-12-31 08:45:00    False
# 2013-12-31 08:45:00    False
# 2014-12-31 08:45:00     True
# 2015-12-31 08:45:00    False
# 2016-12-31 08:45:00     True
# 2017-12-31 08:45:00    False
# 2018-12-31 08:45:00    False
# 2019-12-31 08:45:00     True
# 2020-12-31 08:45:00    False
# Freq: A-DEC, dtype: bool

# %%
from prettytable import PrettyTable
 
 
# open csv file
a = open("new.csv", 'r')
 
# read the csv file
a = a.readlines()
 
# Separating the Headers
l1 = a[0]
l1 = l1.split(',')
 
# headers for table
t = PrettyTable([l1[0], l1[1]])
 
# Adding the data
for i in range(1, len(a)) :
    t.add_row(a[i].split(','))
 
code = t.get_html_string()
html_file = open('Tablee.html', 'w')
html_file = html_file.write(code)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-57-537473a6df95> in <module>
#      17 # Adding the data
#      18 for i in range(1, len(a)) :
# ---> 19     t.add_row(a[i].split(','))
#      20
#      21 code = t.get_html_string()
#
# D:\Anaconda\envs\gpu2\lib\site-packages\prettytable\prettytable.py in add_row(self, row)
#    1344         if self._field_names and len(row) != len(self._field_names):
#    1345             raise Exception(
# -> 1346                 "Row has incorrect number of values, "
#    1347                 f"(actual) {len(row)}!={len(self._field_names)} (expected)"
#    1348             )
#
# Exception: Row has incorrect number of values, (actual) 5!=2 (expected)

# %%
df = pd.DataFrame({'A':[1, 2, 3, 4, 5, 6, 7, 8], 
                   'B':[1, 2, 3, 4, 5, 6, 7, 8], 
                   'C':[1, 2, 3, 4, 5, 6, 7, 8],
                   'D':[1, 2, 3, 4, 5, 6, 7, 8],
                   'E':[1, 2, 3, 4, 5, 6, 7, 8]})
  
  
df.style.set_table_styles(
[
 {'selector': 'th',
  'props': [('background', '# 606060'), 
            ('color', 'white'), ]},
 {'selector': 'td',
  'props': [('color', 'blue')]},
])
# Out:
# <style  type="text/css" >
#     #T_9249e2f8_d790_11ed_8115_a4b1c13977cb th {
#           background: # 606060;
#           color: white;
#     }    #T_9249e2f8_d790_11ed_8115_a4b1c13977cb td {
#           color: blue;
#     }</style><table id="T_9249e2f8_d790_11ed_8115_a4b1c13977cb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9249e2f8_d790_11ed_8115_a4b1c13977cblevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow0_col1" class="data row0 col1" >1</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow0_col3" class="data row0 col3" >1</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_9249e2f8_d790_11ed_8115_a4b1c13977cblevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow1_col0" class="data row1 col0" >2</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow1_col1" class="data row1 col1" >2</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow1_col2" class="data row1 col2" >2</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow1_col3" class="data row1 col3" >2</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow1_col4" class="data row1 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_9249e2f8_d790_11ed_8115_a4b1c13977cblevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow2_col1" class="data row2 col1" >3</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow2_col2" class="data row2 col2" >3</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow2_col3" class="data row2 col3" >3</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow2_col4" class="data row2 col4" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_9249e2f8_d790_11ed_8115_a4b1c13977cblevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow3_col0" class="data row3 col0" >4</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow3_col1" class="data row3 col1" >4</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow3_col2" class="data row3 col2" >4</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow3_col3" class="data row3 col3" >4</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow3_col4" class="data row3 col4" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_9249e2f8_d790_11ed_8115_a4b1c13977cblevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow4_col0" class="data row4 col0" >5</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow4_col1" class="data row4 col1" >5</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow4_col2" class="data row4 col2" >5</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow4_col3" class="data row4 col3" >5</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow4_col4" class="data row4 col4" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_9249e2f8_d790_11ed_8115_a4b1c13977cblevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow5_col0" class="data row5 col0" >6</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow5_col1" class="data row5 col1" >6</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow5_col2" class="data row5 col2" >6</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow5_col3" class="data row5 col3" >6</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow5_col4" class="data row5 col4" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_9249e2f8_d790_11ed_8115_a4b1c13977cblevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow6_col0" class="data row6 col0" >7</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow6_col1" class="data row6 col1" >7</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow6_col2" class="data row6 col2" >7</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow6_col3" class="data row6 col3" >7</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow6_col4" class="data row6 col4" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_9249e2f8_d790_11ed_8115_a4b1c13977cblevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow7_col0" class="data row7 col0" >8</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow7_col1" class="data row7 col1" >8</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow7_col2" class="data row7 col2" >8</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow7_col3" class="data row7 col3" >8</td>
#                         <td id="T_9249e2f8_d790_11ed_8115_a4b1c13977cbrow7_col4" class="data row7 col4" >8</td>
#             </tr>
#     </tbody></table>
